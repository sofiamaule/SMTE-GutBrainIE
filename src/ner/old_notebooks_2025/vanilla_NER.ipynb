# %% [markdown]
# ## Load Training Data and Extract Entities

# %%
import json
from pathlib import Path
from collections import Counter, defaultdict
PROJECT_ROOT = Path.cwd().parents[1]
DATA_ROOT = PROJECT_ROOT / "data" / "GutBrainIE_Full_Collection_2025"
ANNOTATIONS_DIR = DATA_ROOT / "Annotations"

train_files = [
    ANNOTATIONS_DIR / "Train" / "gold_quality" / "json_format" / "train_gold.json",
    ANNOTATIONS_DIR / "Train" / "platinum_quality" / "json_format" / "train_platinum.json",
    ANNOTATIONS_DIR / "Train" / "silver_quality" / "json_format" / "train_silver.json",
]


# span_norm -> Counter(labels)
label_counts_by_span = defaultdict(Counter)

for train_file in train_files:
    if not train_file.exists():
        raise FileNotFoundError(f"Missing file: {train_file}")

    with train_file.open(encoding="utf-8") as f:
        train_data = json.load(f)

    for _, article in train_data.items():
        for ent in article["entities"]:
            span = (ent["text_span"] or "").strip()
            label = ent["label"]

            if not span:
                continue

            span_norm = span.lower()
            label_counts_by_span[span_norm][label] += 1

    print(f"Loaded {train_file.name}")

def pick_majority_label(counter: Counter) -> str:
    # label più frequente; tie-break deterministico (ordine alfabetico)
    max_count = max(counter.values())
    top = sorted([lbl for lbl, c in counter.items() if c == max_count])
    return top[0]
# Out:
# Loaded train_gold.json
# Loaded train_platinum.json
# Loaded train_silver.json

# %% [markdown]
# ## Load Dev Data

# %%
dev_data_path = (
    ANNOTATIONS_DIR
    / "Dev"
    / "json_format"
    / "dev.json"
)

with dev_data_path.open(encoding="utf-8") as f:
    dev_data = json.load(f)

print(f"Loaded {len(dev_data)} dev documents")
# Out:
# Loaded 40 dev documents

# %% [markdown]
# ## Predict Entities on Dev Set
#
# This section defines the matching + filtering logic and then applies it to each dev document to produce NER predictions.

# %% [markdown]
# #### Label-specific minimum lengths
#
# We define per-label minimum span lengths to suppress systematic noise (e.g., very short “gene” matches that are usually false positives).

# %%
LABEL_MIN_LEN = {
    "gene": 8,
    "biomedical technique": 10,
    "statistical technique": 15,
    "food": 8,
    "dietary supplement": 6,
}

# %% [markdown]
# #### Overlap handling
# We define helper functions to find matches and to remove overlapping predicted spans by keeping the longest span per overlap cluster within the same location (title/abstract).

# %%
from tqdm import tqdm
import re
def find_all_occurrences(text, entity_text):
    """
    Find all occurrences of entity_text in text.
    Returns list of (start_idx, end_idx) tuples.
    """
    occurrences = []
    start = 0
    while True:
        pos = text.find(entity_text, start)
        if pos == -1:
            break
        occurrences.append((pos, pos + len(entity_text)))
        start = pos + 1
    return occurrences

def remove_overlapping_entities(entities):
    """
    Remove overlapping entities, keeping only the longest span.
    entities: list of dicts with start_idx, end_idx, text_span, label, location
    """
    if not entities:
        return []
    
    # Sort by start position, then by length (longest first)
    entities = sorted(entities, key=lambda x: (x['start_idx'], -(x['end_idx'] - x['start_idx'])))
    
    kept = []
    for entity in entities:
        # Check if this entity overlaps with any kept entity
        overlaps = False
        for kept_entity in kept:
            # Check if same location and overlapping spans
            if entity['location'] == kept_entity['location']:
                # Check for overlap
                if not (entity['end_idx'] <= kept_entity['start_idx'] or 
                       entity['start_idx'] >= kept_entity['end_idx']):
                    overlaps = True
                    break
        
        if not overlaps:
            kept.append(entity)
    
    return kept

# %% [markdown]
#  ### Filters + regex token-boundary + ignorecase
# Adds lightweight linguistic constraints (acronym exceptions, per-label min lengths, and label-specific blacklists) and compiles efficient regex patterns for matching.
#
# #### 1-  Acronyms, min-lengths, and blacklists
# We whitelist common biomedical acronyms and blacklist generic terms that frequently generate false positives for specific labels.

# %%
BIOMED_ACRONYMS = {"ad", "pd", "ibd", "cns", "sns"}

LABEL_MIN_LEN = {
    "gene": 8,
    "biomedical technique": 10,
    "statistical technique": 15,
    "food": 8,
    "dietary supplement": 6,
}

LABEL_BLACKLIST = {
    "chemical": {
        "protein", "proteins", "metabolite", "metabolites",
        "compound", "compounds", "enzyme", "enzymes", "antioxidant"
    },
    "gene": {"are", "genetic", "region"},
    "DDF": {"clinical", "changes", "inflammatory", "pathogenesis"},
    "human": {"control", "patients", "host"},
    "bacteria": {"bacteria", "taxa"},
    "animal": {"rats", "mice"},
}

# %% [markdown]
# This function decides whether a candidate span should be discarded based on label-aware rules: acronym allowlist, per-label minimum length, blacklist, and “all non-alphanumeric” spans.

# %%
def is_noise_span(span_norm: str, label: str) -> bool:
    # incklude biomedical acronyms
    if span_norm in BIOMED_ACRONYMS:
        return False

    # min lenght per label
    min_len = LABEL_MIN_LEN.get(label, 3)
    if len(span_norm) < min_len:
        return True

    # blacklist per label
    if span_norm in LABEL_BLACKLIST.get(label, set()):
        return True
    #no spaces
    if all(not ch.isalnum() for ch in span_norm):
        return True

    return False

# %% [markdown]
# We convert the training gazetteer into compiled regex patterns using token-boundary constraints and case-insensitive matching, then sort by span length to prioritize longer matches.

# %%
def compile_patterns(label_counts_by_span):
    patterns = []

    for span_norm, lbl_counter in label_counts_by_span.items():
        label = pick_majority_label(lbl_counter)

        # filtro rumore (QUI è il punto giusto)
        if is_noise_span(span_norm, label):
            continue

        # regex token boundary + ignorecase
        pat = re.compile(
            rf"(?<!\w){re.escape(span_norm)}(?!\w)",
            flags=re.IGNORECASE
        )

        patterns.append((span_norm, pat, label))

    patterns.sort(key=lambda x: len(x[0]), reverse=True)
    return patterns

PATTERNS = compile_patterns(label_counts_by_span)
print("Total patterns after filtering:", len(PATTERNS))
# Out:
# Total patterns after filtering: 7315

# %% [markdown]
# ## Predictions
# - For each pattern, we find all matches, record inclusive end offsets (organizer format), and store the exact substring from the text to preserve casing for exact-match evaluation.
#
# - We drop overlapping predictions within the same location to reduce duplicates and prioritize longer, more specific mentions.

# %%
# Process each document in dev set
predictions = {}

for pmid, article in tqdm(dev_data.items(), desc="Processing dev data"):
    title = article["metadata"]["title"]
    abstract = article["metadata"]["abstract"]

    predicted_entities = []

    for location, text in [("title", title), ("abstract", abstract)]:
        # Per matching ignorecase usiamo anche una versione lower
        text_lower = text.lower()

        for span_norm, regex, label in PATTERNS:
            # finditer sul lower? No: regex è IGNORECASE, lo applichiamo sul testo originale
            for m in regex.finditer(text):
                start_idx = m.start()
                end_excl = m.end()

                # IMPORTANTISSIMO: salva la substring reale del testo (casing esatto)
                matched_text_span = text[start_idx:end_excl]
                # taxonomy filter for bacteria
                if label == "bacteria" and not matched_text_span[0].isupper():
                    continue

                predicted_entities.append({
                    "start_idx": start_idx,
                    "end_idx": end_excl - 1,
                    "location": location,
                    "text_span": matched_text_span,
                    "label": label
                })

    predicted_entities = remove_overlapping_entities(predicted_entities)

    predictions[pmid] = {"entities": predicted_entities}

print(f"\nProcessed {len(predictions)} documents")
print(f"Total entities predicted: {sum(len(p['entities']) for p in predictions.values())}")
# Out:
# Processing dev data: 100%|██████████| 40/40 [00:18<00:00,  2.14it/s]
# Processed 40 documents
# Total entities predicted: 1599

# %% [markdown]
# ## Save Predictions

# %%
# Save predictions to file
PREDICTIONS_DIR = PROJECT_ROOT / "src" / "predictions"
PREDICTIONS_DIR.mkdir(parents=True, exist_ok=True)

output_path = PREDICTIONS_DIR / "vanilla_NER.json"

with open(output_path, "w", encoding="utf-8") as f:
    json.dump(predictions, f, ensure_ascii=False, indent=2)

print(f"Predictions saved to {output_path}")
# Out:
# Predictions saved to C:\Users\super\Documents\UniPd\ATA\GutBrainIE\src\predictions\vanilla_NER.json

# %% [markdown]
# ## Evaluate Performance
#
# - De-duplicate predictions: We remove duplicated predicted entities (same span + location + label) to avoid inflating counts.
#
# - Remove overlaps for evaluation: We apply a stricter overlap removal step (longest-span selection per overlap cluster) to align with typical evaluation expectations.
#
# - Compute macro/micro P/R/F1: We compute per-label true positives and totals, then report both macro-averaged and micro-averaged precision/recall/F1.

# %%
def remove_duplicated_entities(predictions):
    """Remove duplicated entities from predictions."""
    removed_count = 0
    for pmid in list(predictions.keys()):
        seen = set()
        deduped = []
        for ent in predictions[pmid]["entities"]:
            key = (ent["start_idx"], ent["end_idx"], ent["location"], ent["label"])
            if key not in seen:
                seen.add(key)
                deduped.append(ent)
            else:
                removed_count += 1
        predictions[pmid]["entities"] = deduped
    
    if removed_count > 0:
        print(f"Removed {removed_count} duplicated entities from predictions")

def remove_overlapping_entities_eval(predictions):
    """Remove overlapping entities, keeping longest spans."""
    removed_count = 0

    for pmid in list(predictions.keys()):
        original_len = len(predictions[pmid]['entities'])
        
        # Group entities by location
        groups = {'title': [], 'abstract': []}
        for ent in predictions[pmid]['entities']:
            loc = ent["location"]
            groups[loc].append(ent)

        # For each location, build overlap clusters and select the longest
        keepers = set()
        for loc in groups:
            group = groups[loc]
            group = sorted(group, key=lambda e: e["start_idx"])

            clusters = []
            cluster = []
            current_end = None

            for ent in group:
                if not cluster:
                    cluster = [ent]
                    current_end = ent["end_idx"]
                else:
                    if ent["start_idx"] < current_end:
                        cluster.append(ent)
                        if ent["end_idx"] > current_end:
                            current_end = ent["end_idx"]
                    else:
                        clusters.append(cluster)
                        cluster = [ent]
                        current_end = ent["end_idx"]
            if cluster:
                clusters.append(cluster)

            # Pick the longest entity in each cluster
            for clust in clusters:
                longest = clust[0]
                max_len = longest["end_idx"] - longest["start_idx"]
                for ent in clust[1:]:
                    length = ent["end_idx"] - ent["start_idx"]
                    if length > max_len:
                        longest = ent
                        max_len = length
                keepers.add((longest["start_idx"],
                             longest["end_idx"],
                             longest["location"]))

        # Rebuild the entity list
        deduped = []
        for ent in predictions[pmid]['entities']:
            key = (ent["start_idx"], ent["end_idx"], ent["location"])
            if key in keepers:
                deduped.append(ent)
                keepers.remove(key)

        predictions[pmid]["entities"] = deduped
        removed_count += (original_len - len(deduped))

    if removed_count > 0:
        print(f"Removed {removed_count} overlapping entities")

def evaluate_ner(predictions, ground_truth):
    """
    Evaluate NER predictions against ground truth.
    Based on the official evaluation script.
    """
    # Remove duplicated and overlapping entities
    remove_duplicated_entities(predictions)
    remove_overlapping_entities_eval(predictions)
    
    LEGAL_ENTITY_LABELS = [
        "anatomical location",
        "animal",
        "bacteria",
        "biomedical technique",
        "chemical",
        "DDF",
        "dietary supplement",
        "drug",
        "food",
        "gene",
        "human",
        "microbiome",
        "statistical technique"
    ]
    
    ground_truth_NER = dict()
    count_annotated_entities_per_label = {}
    
    for pmid, article in ground_truth.items():
        if pmid not in ground_truth_NER:
            ground_truth_NER[pmid] = []
        for entity in article['entities']:
            start_idx = int(entity["start_idx"])
            end_idx = int(entity["end_idx"])
            location = str(entity["location"])
            text_span = str(entity["text_span"])
            label = str(entity["label"]) 
            
            entry = (start_idx, end_idx, location, text_span, label)
            ground_truth_NER[pmid].append(entry)
            
            if label not in count_annotated_entities_per_label:
                count_annotated_entities_per_label[label] = 0
            count_annotated_entities_per_label[label] += 1

    count_predicted_entities_per_label = {label: 0 for label in list(count_annotated_entities_per_label.keys())}
    count_true_positives_per_label = {label: 0 for label in list(count_annotated_entities_per_label.keys())}

    for pmid in predictions.keys():
        entities = predictions[pmid]['entities']
        
        for entity in entities:
            start_idx = int(entity["start_idx"])
            end_idx = int(entity["end_idx"])
            location = str(entity["location"])
            text_span = str(entity["text_span"])
            label = str(entity["label"]) 
            
            if label not in LEGAL_ENTITY_LABELS:
                print(f'Warning: Illegal label {label} for entity: {entity}')
                continue

            if label in count_predicted_entities_per_label:
                count_predicted_entities_per_label[label] += 1

            entry = (start_idx, end_idx, location, text_span, label)
            if entry in ground_truth_NER[pmid]:
                count_true_positives_per_label[label] += 1

    count_annotated_entities = sum(count_annotated_entities_per_label[label] for label in list(count_annotated_entities_per_label.keys()))
    count_predicted_entities = sum(count_predicted_entities_per_label[label] for label in list(count_annotated_entities_per_label.keys()))
    count_true_positives = sum(count_true_positives_per_label[label] for label in list(count_annotated_entities_per_label.keys()))

    micro_precision = count_true_positives / (count_predicted_entities + 1e-10)
    micro_recall = count_true_positives / (count_annotated_entities + 1e-10)
    micro_f1 = 2 * ((micro_precision * micro_recall) / (micro_precision + micro_recall + 1e-10))

    precision, recall, f1 = 0, 0, 0
    n = 0
    for label in list(count_annotated_entities_per_label.keys()):
        n += 1
        current_precision = count_true_positives_per_label[label] / (count_predicted_entities_per_label[label] + 1e-10) 
        current_recall = count_true_positives_per_label[label] / (count_annotated_entities_per_label[label] + 1e-10) 
        
        precision += current_precision
        recall += current_recall
        f1 += 2 * ((current_precision * current_recall) / (current_precision + current_recall + 1e-10))
    
    precision = precision / n
    recall = recall / n
    f1 = f1 / n

    return precision, recall, f1, micro_precision, micro_recall, micro_f1

# Evaluate
precision, recall, f1, micro_precision, micro_recall, micro_f1 = evaluate_ner(predictions, dev_data)

print("="*60)
print("VANILLA NER BASELINE RESULTS")
print("="*60)
print("\nMacro-averaged Metrics:")
print(f"  Macro-Precision: {precision:.4f}")
print(f"  Macro-Recall:    {recall:.4f}")
print(f"  Macro-F1 Score:  {f1:.4f}")

print("\nMicro-averaged Metrics:")
print(f"  Micro-Precision: {micro_precision:.4f}")
print(f"  Micro-Recall:    {micro_recall:.4f}")
print(f"  Micro-F1 Score:  {micro_f1:.4f}")
print("="*60)
# Out:
# ============================================================
# VANILLA NER BASELINE RESULTS
# ============================================================
#
# Macro-averaged Metrics:
#   Macro-Precision: 0.3913
#   Macro-Recall:    0.4693
#   Macro-F1 Score:  0.3888
#
# Micro-averaged Metrics:
#   Micro-Precision: 0.3977
#   Micro-Recall:    0.5694
#   Micro-F1 Score:  0.4683
# ============================================================

# %% [markdown]
# By introducing case-insensitive matching with token boundaries, majority-label disambiguation, and noise filtering on short spans, the vanilla gazetteer-based NER baseline significantly improves precision while preserving high recall.
#
# The Micro-F1 score increases from 0.38 to 0.43, demonstrating that simple linguistic constraints can substantially reduce false positives without relying on learned models.

# %% [markdown]
# ## Example Predictions

# %%
# Show example predictions
print("Example Predictions:\n")

# Get first few documents
sample_pmids = list(dev_data.keys())[:5]

for pmid in sample_pmids:
    article = dev_data[pmid]
    pred = predictions[pmid]
    
    print(f"Document PMID: {pmid}")
    print(f"Title: {article['metadata']['title'][:100]}...")
    print(f"\nGold entities: {len(article['entities'])}")
    print(f"Predicted entities: {len(pred['entities'])}")
    
    # Show first few predicted entities
    print("\nSample predictions:")
    for entity in pred['entities'][:5]:
        print(f"  - '{entity['text_span']}' [{entity['label']}] in {entity['location']}")
    
    # Calculate match statistics for this document
    gold_set = set()
    for entity in article['entities']:
        gold_set.add((
            entity['start_idx'],
            entity['end_idx'],
            entity['location'],
            entity['text_span'],
            entity['label']
        ))
    
    pred_set = set()
    for entity in pred['entities']:
        pred_set.add((
            entity['start_idx'],
            entity['end_idx'],
            entity['location'],
            entity['text_span'],
            entity['label']
        ))
    
    correct = len(gold_set & pred_set)
    missed = len(gold_set - pred_set)
    wrong = len(pred_set - gold_set)
    
    print(f"\n✓ Correct: {correct}")
    print(f"✗ Missed: {missed}")
    print(f"✗ Wrong: {wrong}")
    print("-" * 80)
    print()
# Out:
# Example Predictions:
#
# Document PMID: 36532064
# Title: Hypothesis of a potential BrainBiota and its relation to CNS autoimmune inflammation....
#
# Gold entities: 19
# Predicted entities: 21
#
# Sample predictions:
#   - 'agents' [drug] in abstract
#   - 'CNS' [anatomical location] in title
#   - 'inflammation' [DDF] in title
#   - 'neurological diseases' [DDF] in abstract
#   - 'CNS autoimmunity' [DDF] in abstract
#
# ✓ Correct: 12
# ✗ Missed: 7
# ✗ Wrong: 9
# --------------------------------------------------------------------------------
#
# Document PMID: 37212075
# Title: IgA-Biome Profiles Correlate with Clinical Parkinson's Disease Subtypes....
#
# Gold entities: 21
# Predicted entities: 21
#
# Sample predictions:
#   - 'Parkinson's disease' [DDF] in abstract
#   - 'neurodegenerative disorder' [DDF] in abstract
#   - 'Parkinson's Disease' [DDF] in title
#   - 'gut microbiome' [microbiome] in abstract
#   - 'gut microbiota' [microbiome] in abstract
#
# ✓ Correct: 5
# ✗ Missed: 16
# ✗ Wrong: 16
# --------------------------------------------------------------------------------
#
# Document PMID: 37577447
# Title: The association between oral and gut microbiota in male patients with alcohol dependence....
#
# Gold entities: 34
# Predicted entities: 34
#
# Sample predictions:
#   - 'oral and gut microbiota' [microbiome] in title
#   - 'oral and gut microbiota' [microbiome] in abstract
#   - 'male patients' [human] in title
#   - 'AD' [DDF] in abstract
#   - 'effects' [DDF] in abstract
#
# ✓ Correct: 26
# ✗ Missed: 8
# ✗ Wrong: 8
# --------------------------------------------------------------------------------
#
# Document PMID: 38203207
# Title: Our Mental Health Is Determined by an Intrinsic Interplay between the Central Nervous System, Enteri...
#
# Gold entities: 34
# Predicted entities: 50
#
# Sample predictions:
#   - 'Mental Health' [DDF] in title
#   - 'gut microbiome' [microbiome] in abstract
#   - 'Central Nervous System' [anatomical location] in title
#   - 'intestinal permeability' [DDF] in abstract
#   - 'Gut Microbiota' [microbiome] in title
#
# ✓ Correct: 26
# ✗ Missed: 8
# ✗ Wrong: 24
# --------------------------------------------------------------------------------
#
# Document PMID: 31530799
# Title: Abnormal composition of gut microbiota is associated with resilience versus susceptibility to inesca...
#
# Gold entities: 33
# Predicted entities: 28
#
# Sample predictions:
#   - 'Abnormal composition of gut microbiota' [DDF] in title
#   - 'gut microbiota' [microbiome] in abstract
#   - 'stress-related disorders' [DDF] in abstract
#   - 'stress' [DDF] in title
#   - 'stress' [DDF] in abstract
#
# ✓ Correct: 14
# ✗ Missed: 19
# ✗ Wrong: 14
# --------------------------------------------------------------------------------

# %% [markdown]
# ## Analysis: Entity Distribution by Label

# %%
from collections import Counter

# Count entities by label in predictions
pred_label_counts = Counter()
for pmid, pred in predictions.items():
    for entity in pred['entities']:
        pred_label_counts[entity['label']] += 1

# Count entities by label in gold standard
gold_label_counts = Counter()
for pmid, article in dev_data.items():
    for entity in article['entities']:
        gold_label_counts[entity['label']] += 1

print("Entity Distribution by Label:")
print("="*60)
print(f"{'Label':<25} {'Gold':<10} {'Predicted':<10}")
print("-"*60)

all_labels = set(gold_label_counts.keys()) | set(pred_label_counts.keys())
for label in sorted(all_labels):
    print(f"{label:<25} {gold_label_counts[label]:<10} {pred_label_counts[label]:<10}")

print("-"*60)
print(f"{'TOTAL':<25} {sum(gold_label_counts.values()):<10} {sum(pred_label_counts.values()):<10}")
# Out:
# Entity Distribution by Label:
# ============================================================
# Label                     Gold       Predicted
# ------------------------------------------------------------
# DDF                       379        574
# anatomical location       76         217
# animal                    73         53
# bacteria                  54         51
# biomedical technique      36         39
# chemical                  131        187
# dietary supplement        27         40
# drug                      60         102
# food                      26         6
# gene                      39         4
# human                     86         102
# microbiome                127        219
# statistical technique     3          5
# ------------------------------------------------------------
# TOTAL                     1117       1599

# %% [markdown]
# ## Error inspection
# This section performs an error analysis by collecting false positives (FP), false negatives (FN), and true positives (TP) per label.

# %%
from collections import defaultdict

false_positives = defaultdict(list)
false_negatives = defaultdict(list)
true_positives = defaultdict(list)

for pmid, article in dev_data.items():
    gold = {
        (e["start_idx"], e["end_idx"], e["location"], e["text_span"], e["label"])
        for e in article["entities"]
    }
    pred = {
        (e["start_idx"], e["end_idx"], e["location"], e["text_span"], e["label"])
        for e in predictions[pmid]["entities"]
    }

    for e in pred - gold:
        false_positives[e[4]].append(e)

    for e in gold - pred:
        false_negatives[e[4]].append(e)

    for e in gold & pred:
        true_positives[e[4]].append(e)

# %% [markdown]
# #### Top false positives per label
# We print a small sample of FP examples per label to identify systematic noise sources (generic terms, short spans, overly broad concepts).

# %%
for label, ents in false_positives.items():
    print(f"\n[FP] {label} ({len(ents)})")
    for e in ents[:10]:
        print(" ", e)
# Out:
# [FP] anatomical location (152)
#   (434, 447, 'abstract', 'gut-brain axis', 'anatomical location')
#   (57, 59, 'title', 'CNS', 'anatomical location')
#   (481, 485, 'abstract', 'brain', 'anatomical location')
#   (839, 843, 'abstract', 'brain', 'anatomical location')
#   (549, 553, 'abstract', 'brain', 'anatomical location')
#   (618, 622, 'abstract', 'stool', 'anatomical location')
#   (896, 898, 'abstract', 'gut', 'anatomical location')
#   (1200, 1204, 'abstract', 'blood', 'anatomical location')
#   (70, 91, 'title', 'Central Nervous System', 'anatomical location')
#   (190, 211, 'abstract', 'central nervous system', 'anatomical location')
#
# [FP] microbiome (107)
#   (487, 496, 'abstract', 'microbiota', 'microbiome')
#   (83, 96, 'abstract', 'gut microbiome', 'microbiome')
#   (912, 921, 'abstract', 'microbiota', 'microbiome')
#   (397, 409, 'abstract', 'gut microbial', 'microbiome')
#   (1044, 1064, 'abstract', 'intestinal microbiota', 'microbiome')
#   (1335, 1348, 'abstract', 'gut microbiota', 'microbiome')
#   (16, 29, 'abstract', 'gut microbiome', 'microbiome')
#   (379, 404, 'abstract', 'gut microbiota composition', 'microbiome')
#   (294, 307, 'abstract', 'microbial taxa', 'microbiome')
#   (2099, 2116, 'abstract', 'gut microbial taxa', 'microbiome')
#
# [FP] DDF (328)
#   (663, 671, 'abstract', 'bacterial', 'DDF')
#   (72, 83, 'title', 'inflammation', 'DDF')
#   (1341, 1355, 'abstract', 'immune response', 'DDF')
#   (43, 61, 'title', "Parkinson's Disease", 'DDF')
#   (406, 420, 'abstract', 'tremor dominant', 'DDF')
#   (870, 888, 'abstract', "Parkinson's disease", 'DDF')
#   (39, 64, 'abstract', 'neurodegenerative disorder', 'DDF')
#   (427, 445, 'abstract', "Parkinson's disease", 'DDF')
#   (1082, 1090, 'abstract', 'bacterial', 'DDF')
#   (196, 202, 'abstract', 'disease', 'DDF')
#
# [FP] drug (80)
#   (11, 16, 'abstract', 'agents', 'drug')
#   (1270, 1280, 'abstract', 'therapeutic', 'drug')
#   (2007, 2017, 'abstract', 'therapeutic', 'drug')
#   (208, 225, 'abstract', 'therapeutic agents', 'drug')
#   (2099, 2109, 'abstract', 'therapeutic', 'drug')
#   (459, 469, 'abstract', 'therapeutic', 'drug')
#   (1483, 1493, 'abstract', 'therapeutic', 'drug')
#   (497, 511, 'abstract', 'pharmacological', 'drug')
#   (741, 751, 'abstract', 'therapeutic', 'drug')
#   (61, 69, 'title', 'Treatment', 'drug')
#
# [FP] statistical technique (4)
#   (1643, 1661, 'abstract', 'microbiome analysis', 'statistical technique')
#   (420, 436, 'abstract', 'PRISMA guidelines', 'statistical technique')
#   (905, 932, 'abstract', 'food frequency questionnaire', 'statistical technique')
#   (348, 375, 'abstract', 'food frequency questionnaire', 'statistical technique')
#
# [FP] bacteria (19)
#   (909, 918, 'abstract', 'Firmicutes', 'bacteria')
#   (920, 930, 'abstract', 'Bacteroides', 'bacteria')
#   (1340, 1352, 'abstract', 'Lactobacillus', 'bacteria')
#   (916, 926, 'abstract', 'Clostridium', 'bacteria')
#   (1427, 1432, 'abstract', 'Genera', 'bacteria')
#   (0, 22, 'title', 'Lactobacillus fermentum', 'bacteria')
#   (407, 429, 'abstract', 'Lactobacillus fermentum', 'bacteria')
#   (1305, 1317, 'abstract', 'Bacteroidetes', 'bacteria')
#   (1490, 1502, 'abstract', 'Lactobacillus', 'bacteria')
#   (1291, 1300, 'abstract', 'Firmicutes', 'bacteria')
#
# [FP] gene (3)
#   (713, 721, 'abstract', 'V4 region', 'gene')
#   (435, 442, 'abstract', '16S rRNA', 'gene')
#   (630, 651, 'abstract', '16S ribosomal RNA gene', 'gene')
#
# [FP] biomedical technique (29)
#   (695, 704, 'abstract', 'sequencing', 'biomedical technique')
#   (339, 355, 'abstract', '16S rRNA sequence', 'biomedical technique')
#   (503, 515, 'abstract', 'fecal samples', 'biomedical technique')
#   (1061, 1074, 'abstract', 'bioinformatics', 'biomedical technique')
#   (706, 725, 'abstract', 'network pharmacology', 'biomedical technique')
#   (176, 189, 'abstract', 'administration', 'biomedical technique')
#   (795, 805, 'abstract', 'β-diversity', 'biomedical technique')
#   (720, 743, 'abstract', '16S rRNA gene sequencing', 'biomedical technique')
#   (776, 789, 'abstract', 'administration', 'biomedical technique')
#   (456, 465, 'abstract', 'sequencing', 'biomedical technique')
#
# [FP] dietary supplement (21)
#   (619, 624, 'abstract', 'fibers', 'dietary supplement')
#   (1286, 1297, 'abstract', 'psychobiotic', 'dietary supplement')
#   (504, 509, 'abstract', 'fibers', 'dietary supplement')
#   (709, 721, 'abstract', 'dietary fiber', 'dietary supplement')
#   (38, 44, 'abstract', 'dietary', 'dietary supplement')
#   (1085, 1093, 'abstract', 'prebiotic', 'dietary supplement')
#   (1433, 1439, 'abstract', 'dietary', 'dietary supplement')
#   (2120, 2126, 'abstract', 'Dietary', 'dietary supplement')
#   (676, 682, 'abstract', 'dietary', 'dietary supplement')
#   (614, 620, 'abstract', 'dietary', 'dietary supplement')
#
# [FP] chemical (131)
#   (1079, 1095, 'abstract', 'neurotransmitters', 'chemical')
#   (257, 287, 'abstract', 'short-chain fatty acids (SCFAs)', 'chemical')
#   (592, 602, 'abstract', 'neuroactive', 'chemical')
#   (2032, 2042, 'abstract', 'neuroactive', 'chemical')
#   (2426, 2435, 'abstract', 'flavonoids', 'chemical')
#   (830, 848, 'abstract', 'bioactive flavonoid', 'chemical')
#   (2722, 2730, 'abstract', 'flavonoid', 'chemical')
#   (950, 958, 'abstract', 'flavonoid', 'chemical')
#   (32, 40, 'title', 'Flavonoid', 'chemical')
#   (1441, 1449, 'abstract', 'flavonoid', 'chemical')
#
# [FP] human (55)
#   (346, 349, 'abstract', 'male', 'human')
#   (1349, 1353, 'abstract', 'adult', 'human')
#   (1355, 1360, 'abstract', 'humans', 'human')
#   (1194, 1211, 'abstract', 'healthy population', 'human')
#   (1594, 1604, 'abstract', 'populations', 'human')
#   (310, 320, 'abstract', 'generations', 'human')
#   (360, 369, 'abstract', 'inpatients', 'human')
#   (964, 976, 'abstract', 'control group', 'human')
#   (921, 925, 'abstract', 'group', 'human')
#   (0, 10, 'abstract', 'Researchers', 'human')
#
# [FP] animal (32)
#   (1373, 1384, 'abstract', 'three groups', 'animal')
#   (448, 453, 'abstract', 'BALB/c', 'animal')
#   (676, 681, 'abstract', 'BALB/c', 'animal')
#   (459, 470, 'abstract', 'C57BL/6 mice', 'animal')
#   (687, 698, 'abstract', 'C57BL/6 mice', 'animal')
#   (1336, 1341, 'abstract', 'BALB/c', 'animal')
#   (1706, 1712, 'abstract', 'animals', 'animal')
#   (102, 104, 'title', 'rat', 'animal')
#   (1146, 1148, 'abstract', 'rat', 'animal')
#   (1758, 1764, 'abstract', 'animals', 'animal')
#
# [FP] food (2)
#   (478, 491, 'abstract', 'alcohol intake', 'food')
#   (201, 214, 'abstract', 'dairy products', 'food')

# %% [markdown]
# #### Span-length analysis
# We compare the span-length distributions (quartiles) for FP vs TP per label to decide where label-specific minimum lengths or additional constraints help the most.

# %%
import numpy as np

def span_len(e):
    return e[1] - e[0] + 1

def analyze_lengths(ents):
    return np.percentile([span_len(e) for e in ents], [25, 50, 75])

for label in false_positives:
    print(
        label,
        "FP len quartiles:", analyze_lengths(false_positives[label]),
        "TP len quartiles:", analyze_lengths(true_positives.get(label, []))
    )
# Out:
# anatomical location FP len quartiles: [5. 5. 9.] TP len quartiles: [ 5.  5. 11.]
# microbiome FP len quartiles: [10. 14. 17.] TP len quartiles: [14. 14. 14.]
# DDF FP len quartiles: [ 7.  9. 13.] TP len quartiles: [10. 17. 21.]
# drug FP len quartiles: [ 9.  9. 11.] TP len quartiles: [10.   11.   11.75]
# statistical technique FP len quartiles: [18.5 23.5 28. ] TP len quartiles: [40. 40. 40.]
# bacteria FP len quartiles: [10.  13.  17.5] TP len quartiles: [11.75 13.   15.  ]
# gene FP len quartiles: [ 8.5  9.  15.5] TP len quartiles: [20. 20. 20.]
# biomedical technique FP len quartiles: [14. 14. 17.] TP len quartiles: [18.   19.   19.75]
# dietary supplement FP len quartiles: [7. 7. 9.] TP len quartiles: [10. 10. 13.]
# chemical FP len quartiles: [ 5.  9. 12.] TP len quartiles: [ 6. 11. 18.]
# human FP len quartiles: [ 5.  7. 10.] TP len quartiles: [ 8.5 12.  16. ]
# animal FP len quartiles: [ 6.   8.5 12. ] TP len quartiles: [10. 16. 16.]
# food FP len quartiles: [14. 14. 14.] TP len quartiles: [14. 14. 14.]

# %% [markdown]
# #### Per-label error summary
#
# This final cell prints TP/FP/FN counts per label to quickly spot which labels are the main precision bottlenecks and which labels suffer from low recall.

# %%
for label in false_negatives:
    fn = len(false_negatives[label])
    tp = len(true_positives.get(label, []))
    fp = len(false_positives.get(label, []))
    print(f"{label:25s} TP={tp:4d} FP={fp:4d} FN={fn:4d}")
# Out:
# microbiome                TP= 112 FP= 107 FN=  15
# chemical                  TP=  56 FP= 131 FN=  75
# DDF                       TP= 246 FP= 328 FN= 133
# human                     TP=  47 FP=  55 FN=  39
# gene                      TP=   1 FP=   3 FN=  38
# biomedical technique      TP=  10 FP=  29 FN=  26
# bacteria                  TP=  32 FP=  19 FN=  22
# statistical technique     TP=   1 FP=   4 FN=   2
# anatomical location       TP=  65 FP= 152 FN=  11
# animal                    TP=  21 FP=  32 FN=  52
# food                      TP=   4 FP=   2 FN=  22
# dietary supplement        TP=  19 FP=  21 FN=   8
# drug                      TP=  22 FP=  80 FN=  38
